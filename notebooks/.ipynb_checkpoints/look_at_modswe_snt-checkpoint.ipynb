# %%
import xarray as xr
import xesmf as xe
import numpy as np 
import pathlib as pl
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
#ls /home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0410_morrison_2019/

# %%
dsmp10_19 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0410_morrison_2019/model_out.nc")
dsmp55_19 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0410_ishmael_2019/model_out.nc")
dsmp08_19 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0410_thompson_2019/model_out.nc")

dsmp10_18 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0308_morrison_swcorr/model_out.nc")
dsmp55_18 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0308_ishmael_swcorr/model_out.nc")
dsmp08_18 = xr.open_dataset("/home/wrudisill/scratch/EastLSM_Only/250m_ModelRuns/model_outputs/model_out_0308_thompson_swcorr/model_out.nc")

# %%
# GET the snotel data

# %%
data_path = "../"
data_path = "../"
database = data_path + "/CO_snotel.db"
dbengine = "sqlite:///{}".format(database)

df_butte     = pd.read_sql_table('380', dbengine)
df_butte = df_butte.set_index("Date")

# %%
# get the aso data and hte lat lons..

# %%
aso_dat1 = pl.Path("../250m_ModelRuns/regrid250m_ASO_50M_SWE_USCOGE_20180331_clipped_nobuffer_latlon.nc")
aso_dat2 = pl.Path("../250m_ModelRuns/regrid250m_ASO_50M_SWE_USCOGE_20190407_clipped_nobuffer_latlon.nc")

swe1=xr.open_dataset(aso_dat1)
swe2=xr.open_dataset(aso_dat2)

# swe = swe.rename({'__xarray_dataarray_variable__':'swe', 'lon': 'longitude', 'lat': 'latitude'})
# swe = swe.drop(['time', 'band'])
swevar1 = swe1.where(swe1>0).swe*1000
swevar2 = swe2.where(swe2>0).swe*1000

def get_aso_xy(lat, lon):
    #lat = 38.89
    #lon = -106.95
    xlat = swevar1.lat.values
    xlon = swevar1.lon.values
    dist = np.sqrt((xlat - lat)**2 + (xlon - lon)**2)
    mindist = dist.min()
    ixlat = np.argwhere(dist == mindist)[0][0]
    ixlon = np.argwhere(dist == mindist)[0][1]
    return {"south_north":slice(ixlat-1, ixlat+1), "west_east":slice(ixlon-1,ixlon+1)}


def get_lsm_xy(lat, lon):
    #lat = 38.89
    #lon = -106.95
    xlat = swevar1.lat.values
    xlon = swevar1.lon.values
    dist = np.sqrt((xlat - lat)**2 + (xlon - lon)**2)
    mindist = dist.min()
    ixlat = np.argwhere(dist == mindist)[0][0]
    ixlon = np.argwhere(dist == mindist)[0][1]
    return {"x":slice(ixlat-1, ixlat+1), "y":slice(ixlon-1,ixlon+1)}





bute_lat, bute_lon = 38.89, -106.95

# %%
# Out:
# <xarray.DataArray 'swe' (band: 1)>
# array([221.56221398])
# Dimensions without coordinates: band

# %%
get_lsm_xy(bute_lat, bute_lon)
# Out:
# {'x': slice(103, 105, None), 'y': slice(65, 67, None)}

# %%
fig,ax = plt.subplots(2,1)
fig.set_size_inches(12,12)

times=pd.date_range("2017-10-01", "2018-03-30", freq='1D')
dsmp08_18.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[0])
dsmp10_18.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[0])
dsmp55_18.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[0])
x = pd.to_datetime("2018-03-31")
ax[0].scatter(x, swevar1.sel(get_aso_xy(bute_lat, bute_lon)).mean(dim=("south_north", "west_east")))             
(df_butte.loc[times].SWE*25.4).plot(ax=ax[0])
#(df_butte.loc["2018-10-01":"2019-05-01"].AccPrecip*25.4).plot(ax=ax[1,0])




times=pd.date_range("2018-10-01", "2019-04-15", freq='1D')
dsmp08_19.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[1])
dsmp10_19.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[1])
dsmp55_19.SNEQV.isel(get_lsm_xy(bute_lat, bute_lon)).mean(dim=("x","y")).sel(time=times).plot(ax=ax[1])
(df_butte.loc[times].SWE*25.4).plot(ax=ax[1])

x = pd.to_datetime("2019-04-07")
swevar1.sel(get_aso_xy(bute_lat, bute_lon)).mean

ax[1].scatter(x, swevar2.sel(get_aso_xy(bute_lat, bute_lon)).mean(dim=("south_north", "west_east")))

# %%
#(df_butte.loc["2018-10-01":"2019-05-01"].SWE*25.4).plot(ax=ax[1,0])
# (df_butte.loc["2018-10-01":"2019-05-01"].SWE*25.4).plot(ax=ax[1,0])
# (df_butte.loc["2018-10-01":"2019-05-01"].AccPrecip*25.4).plot(ax=ax[1,0])

# %%
dsmp10_18.ACCPRCP.isel(y=100,x=50).plot()
dsmp10_18.SNEQV.isel(y=100,x=50).plot()
#dsmp10_18.ACSNOM.isel(y=100,x=50).plot()

# %%
def get_aso_xy(lat, lon):
    #lat = 38.89
    #lon = -106.95
    xlat = swevar1.lat.values
    xlon = swevar1.lon.values
    dist = np.sqrt((xlat - lat)**2 + (xlon - lon)**2)
    mindist = dist.min()
    ixlat = np.argwhere(dist == mindist)[0][0]
    ixlon = np.argwhere(dist == mindist)[0][1]
    return {"south_north":slice(ixlat-1, ixlat+1), "west_east":slice(ixlon-1,ixlon+1)}
